# %%
import pandas as pd

data = pd.read_csv("gl_report.csv")
data
# Out:
#              Company Account Name  Account Number        Date  \
# 0   Demo_Company_001         Bank            1010  2023-01-05
# 1   Demo_Company_001         Bank            1010  2023-01-10
# 2   Demo_Company_001         Bank            1010  2023-01-15
# 3   Demo_Company_001         Bank            1010  2023-01-20
# 4   Demo_Company_001         Bank            1010  2023-01-25
# 5   Demo_Company_001         Bank            1010  2023-01-30
# 6   Demo_Company_002  Credit Card            2050  2023-02-02
# 7   Demo_Company_002  Credit Card            2050  2023-02-15
# 8   Demo_Company_002  Credit Card            2050  2023-02-20
# 9   Demo_Company_002  Credit Card            2050  2023-03-01
# 10  Demo_Company_002  Credit Card            2050  2023-03-05
# 11  Demo_Company_002  Credit Card            2050  2023-03-10
#
#                Description   Debit  Credit  Balance
# 0           Client Payment  1000.0     0.0   1000.0
# 1              Office Rent     0.0   500.0    500.0
# ...
